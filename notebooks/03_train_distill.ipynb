# %% [markdown]
# # 03 — Condition 3: distillation-guided student (treatment)
#
# Same data/LoRA setup as `02_train_sft.ipynb`, but the loss adds a KD term against teacher (Qwen3-14B) logits. This is the condition the research question is actually about — everything else must match condition 2 exactly so the comparison isolates the effect of distillation itself.
#
# See `src/adbench/training/distill_train.py` and `src/adbench/training/losses.py` (both TODO).

# %%
# !python -m adbench.training.distill_train --models-config configs/models.yaml --data-config configs/data.yaml

# %% [markdown]
# ## Save / sanity-check the adapter
#
# TODO: confirm `checkpoints/distilled/` was written, plot the SFT-loss and KD-loss curves side by side, run the same smoke-test prompt as in notebook 02 for a quick eyeball comparison.
