# %% [markdown]
# # 04 — Evaluation: all three conditions
#
# Runs base / SFT-only / distilled students through the agentic harness at chain lengths 1, 3, 5, plus the general-LM perplexity baseline. This is the first and only notebook that touches the held-out `data/splits/test.jsonl`.
#
# See `src/adbench/evaluation/run_eval.py` (TODO).

# %%
# !python -m adbench.evaluation.run_eval --config configs/experiment.yaml

# %% [markdown]
# ## Results
#
# TODO once run_eval.py produces `results/summary.json`:
# - Table: success rate x (condition, chain length)
# - Plot: success rate vs chain length, one line per condition — the key figure for the research question
# - Table: perplexity per condition (general LM comparison)
# - Error-recovery rate per condition (protocol errors vs tool-execution errors, from `harness/errors.py`)
