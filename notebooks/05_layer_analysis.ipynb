# %% [markdown]
# # 05 — Layer-wise activation analysis
#
# Compares teacher (Qwen3-14B) vs distilled student activations on the same probe inputs, per layer, split by attention vs FFN, to localize where the representational gap originates.
#
# See `src/adbench/analysis/layer_analysis.py` (TODO) and `configs/models.yaml`'s `layer_alignment` block for how teacher/student layers of different depths are matched up.

# %%
# from adbench.analysis.layer_analysis import extract_activations, divergence
# teacher_acts = extract_activations(teacher_model, tokenizer, probe_texts, layers=...)
# student_acts = extract_activations(student_model, tokenizer, probe_texts, layers=...)
# per_layer_divergence = {L: divergence(student_acts[L], teacher_acts[L], metric="cka") for L in ...}

# %% [markdown]
# ## Plot
#
# TODO: divergence (CKA / cosine distance) vs layer depth, one line for attention outputs and one for FFN outputs — the key figure for the "which layers" half of the research question.
