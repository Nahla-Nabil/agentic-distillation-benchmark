# %% [markdown]
# # 02 — Condition 2: SFT-only student (control)
#
# Fine-tunes Qwen3-4B-Instruct-2507 on `data/splits/train.jsonl` with Unsloth, no teacher involved. Requires the Colab GPU runtime (`00_setup_colab.ipynb` run first).
#
# See `src/adbench/training/sft_train.py` (TODO).

# %%
# !python -m adbench.training.sft_train --models-config configs/models.yaml --data-config configs/data.yaml

# %% [markdown]
# ## Save / sanity-check the adapter
#
# TODO: confirm `checkpoints/sft_only/` was written, plot the training loss curve, run one manual tool-call prompt through the fine-tuned model as a smoke test.
